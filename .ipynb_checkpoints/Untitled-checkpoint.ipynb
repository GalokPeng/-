# %%
import requests
import re
import os
import json

os.remove('新冠疫情各省数据.csv') 
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'
}
r = requests.get('https://voice.baidu.com/act/newpneumonia/newpneumonia/?from=osari_aladin_banner', headers=headers)
r.encoding = r.apparent_encoding
match = '<script type="application/json" id="captain-config">(.*?)</script>'
data = re.findall(match, r.text, re.S)
js = json.loads(data[0])

with open(r'新冠疫情各省数据.csv', 'a', encoding='utf-8')as f:
    f.write('省份,累积确诊,累积治愈,现有确诊,新增确诊,累积死亡\n')
    f.close()

with open(r'新冠疫情各省数据.csv', 'a', encoding='utf-8')as f:
    for i in js['component'][0]['caseList']:
        shengfen = i['area']
        ljqz = i['confirmed']
        ljzy = i['crued']
        xyqz = i['curConfirm']
        xzqz = i['confirmedRelative']
        ljsw = i['died']
        # print(shengfen, ljqz, ljzy, xyqz, xzqz, ljsw)
        f.write(
            '{},{},{},{},{},{}\n'.format(shengfen,ljqz,ljzy,xyqz,xzqz,ljsw))

# %%
import pandas as pd
data = pd.read_csv('新冠疫情各省数据.csv')
data.head(10)
# Out:
#      ʡ��   �ۻ�ȷ��  �ۻ�����  ����ȷ��  ����ȷ��.1  �ۻ�����.1
# 0   ����        1        1        0          0          0
# 1   ����      189       83      106         17          0
# 2     �ຣ      147      147        0          0          0
# 3    ̨��  3686338    13742  3666148      44417       6448
# 4    ���   337306    63798   264109        364       9399
# 5   ����      185      183        0          0          2
# 6   ����    40295    40290        0          0          5
# 7    �½�     1008     1005        0          0          3
# 8   ����      122      122        0          0          0
# 9  ���ɹ�     2097     2038       58          0          1

# %%
value1 = data['累积确诊']
value2 = data['现有确诊']
value3 = data['累积治愈']
value4 = data['累积死亡']
value1.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\bianchenglei\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '累积确诊'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-80efbb1e6991> in <module>
# ----> 1 value1 = data['累积确诊']
#       2 value2 = data['现有确诊']
#       3 value3 = data['累积治愈']
#       4 value4 = data['累积死亡']
#       5 value1.head(10)
#
# e:\bianchenglei\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# e:\bianchenglei\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '累积确诊'

# %%
v1=data['累积确诊'].sum() #计算全国累积确诊人数
v2=data['现有确诊'].sum() #计算全国现有确诊人数
v3=data['累积治愈'].sum() #计算全国已治愈人数
v4=data['累积死亡'].sum() #计算全国总死亡人数
# print(v1/34,v2/34,v3/34,v4/34)#各平均数
print(v2+v3+v4)
print(v1)#判断数据
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\bianchenglei\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '累积确诊'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-f81481b51208> in <module>
# ----> 1 v1=data['累积确诊'].sum() #计算全国累积确诊人数
#       2 v2=data['现有确诊'].sum() #计算全国现有确诊人数
#       3 v3=data['累积治愈'].sum() #计算全国已治愈人数
#       4 v4=data['累积死亡'].sum() #计算全国总死亡人数
#       5 # print(v1/34,v2/34,v3/34,v4/34)#各平均数
#
# e:\bianchenglei\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# e:\bianchenglei\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '累积确诊'

# %%
from pyecharts import Pie
from pyecharts import online
online()
attr = ['确诊','已治愈','已死亡']
vvz = [v2,v3,v4]
pie = Pie("疫情影响占比图")
pie.add("",attr,vvz)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fede623f3bc64e1ab612666f7654b90b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fede623f3bc64e1ab612666f7654b90b = echarts.init(document.getElementById('fede623f3bc64e1ab612666f7654b90b'), 'light', {renderer: 'canvas'});
#
# var option_fede623f3bc64e1ab612666f7654b90b = {
#     "title": [
#         {
#             "text": "\u75ab\u60c5\u5f71\u54cd\u5360\u6bd4\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6240017,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u786e\u8bca",
#                     "value": "01060366614826410900005812012101141604785469161461102092113\u73b0\u6709\u786e\u8bca01060366614826410900005812012101141604785469161461102092113"
#                 },
#                 {
#                     "name": "\u5df2\u6cbb\u6108",
#                     "value": "183147137426379818340290100512220386791985422171429742821999331221561647337462560362522382355273013827151059139531617343314363887\u7d2f\u79ef\u6cbb\u6108183147137426379818340290100512220386791985422171429742821999331221561647337462560362522382355273013827151059139531617343314363887"
#                 },
#                 {
#                     "name": "\u5df2\u6b7b\u4ea1",
#                     "value": "00064489399253012302136732215959037166422814512\u7d2f\u79ef\u6b7b\u4ea100064489399253012302136732215959037166422814512"
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 6240017
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca",
#                 "\u5df2\u6cbb\u6108",
#                 "\u5df2\u6b7b\u4ea1"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_fede623f3bc64e1ab612666f7654b90b.setOption(option_fede623f3bc64e1ab612666f7654b90b);
#
#     });
# </script>

# %%
#查看全国疫情最严重的10个省份
top10=data.sort_values('累积确诊',ascending=False).head(10)
top10
# Out:
#     省份   累积确诊   累积治愈  现有确诊  新增确诊  累积死亡
# 34  省份   累积确诊   累积治愈  现有确诊  新增确诊  累积死亡
# 66  广东   7443   7343    92     7     8
# 31  广东   7443   7343    92     7     8
# 27  重庆    732    715    11     3     6
# 62  重庆    732    715    11     3     6
# 33  湖北  68402  63887     3     0  4512
# 68  湖北  68402  63887     3     0  4512
# 45  甘肃    682    679     1     0     2
# 10  甘肃    682    679     1     0     2
# 21  上海  63240  62560    85     1   595

# %%
#柱形图显示
from pyecharts import Bar
import pandas as pd 
from pyecharts import online
online()

data = pd.read_csv('新冠疫情各省数据.csv')
x = top10['省份'].tolist()
# x=['西藏','澳门','青海','台湾','香港','贵州','吉林','新疆','宁夏','内蒙古','甘肃','天津','山西','辽宁','黑龙江','海南',
#    '河北','陕西','云南','广西','福建','上海','北京','江苏','四川','山东','江西','重庆','安徽','湖南','河南','广东','浙江','湖北']
# 
y1 = top10['累积确诊'].tolist()
y2 = top10['累积治愈'].tolist()
y3 = top10['累积死亡'].tolist()
y4 = top10['现有确诊'].tolist()
fig=Bar()
fig.add('新冠疫情各省累积确诊人数', x, y1)
fig.add('新冠疫情各省累积治愈人数', x, y2)
fig.add('新冠疫情各省累积死亡人数', x, y3)
fig.add('新冠疫情各省现有确诊人数', x, y4)
# fig.render("各数据对比柱状图.html")
fig
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="150f43ca4ccb4618a764479f4b6349d1" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_150f43ca4ccb4618a764479f4b6349d1 = echarts.init(document.getElementById('150f43ca4ccb4618a764479f4b6349d1'), 'light', {renderer: 'canvas'});
#
# var option_150f43ca4ccb4618a764479f4b6349d1 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4378154,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u65b0\u51a0\u75ab\u60c5\u5404\u7701\u7d2f\u79ef\u786e\u8bca\u4eba\u6570",
#             "data": [
#                 "\u7d2f\u79ef\u786e\u8bca",
#                 "7443",
#                 "7443",
#                 "732",
#                 "732",
#                 "68402",
#                 "68402",
#                 "682",
#                 "682",
#                 "63240"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4378154
#         },
#         {
#             "type": "bar",
#             "name": "\u65b0\u51a0\u75ab\u60c5\u5404\u7701\u7d2f\u79ef\u6cbb\u6108\u4eba\u6570",
#             "data": [
#                 "\u7d2f\u79ef\u6cbb\u6108",
#                 "7343",
#                 "7343",
#                 "715",
#                 "715",
#                 "63887",
#                 "63887",
#                 "679",
#                 "679",
#                 "62560"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4378154
#         },
#         {
#             "type": "bar",
#             "name": "\u65b0\u51a0\u75ab\u60c5\u5404\u7701\u7d2f\u79ef\u6b7b\u4ea1\u4eba\u6570",
#             "data": [
#                 "\u7d2f\u79ef\u6b7b\u4ea1",
#                 "8",
#                 "8",
#                 "6",
#                 "6",
#                 "4512",
#                 "4512",
#                 "2",
#                 "2",
#                 "595"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4378154
#         },
#         {
#             "type": "bar",
#             "name": "\u65b0\u51a0\u75ab\u60c5\u5404\u7701\u73b0\u6709\u786e\u8bca\u4eba\u6570",
#             "data": [
#                 "\u73b0\u6709\u786e\u8bca",
#                 "92",
#                 "92",
#                 "11",
#                 "11",
#                 "3",
#                 "3",
#                 "1",
#                 "1",
#                 "85"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4378154
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u65b0\u51a0\u75ab\u60c5\u5404\u7701\u7d2f\u79ef\u786e\u8bca\u4eba\u6570",
#                 "\u65b0\u51a0\u75ab\u60c5\u5404\u7701\u7d2f\u79ef\u6cbb\u6108\u4eba\u6570",
#                 "\u65b0\u51a0\u75ab\u60c5\u5404\u7701\u7d2f\u79ef\u6b7b\u4ea1\u4eba\u6570",
#                 "\u65b0\u51a0\u75ab\u60c5\u5404\u7701\u73b0\u6709\u786e\u8bca\u4eba\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u7701\u4efd",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u4e1c",
#                 "\u91cd\u5e86",
#                 "\u91cd\u5e86",
#                 "\u6e56\u5317",
#                 "\u6e56\u5317",
#                 "\u7518\u8083",
#                 "\u7518\u8083",
#                 "\u4e0a\u6d77"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false

# %%
# coding=utf-8
from ipywidgets import Tab
from pyecharts import Map
import pandas as pd
from pyecharts import online
online()
data = pd.read_csv('新冠疫情各省数据.csv')
atr = []
for i in data['省份']:
    atr.append(i)

valueqz = data['累积确诊']
map = Map("新冠疫情数据", width=800, height=600)
map.add(
    "各省累积确诊人数",
    atr,
    valueqz,
    maptype="china",
    is_label_show=True,
    is_visualmap=True,
    visual_range = [1,20000],
    visual_text_color='#2E2E2E',
    visual_range_color=['white','orange','red'],
    is_map_symbol_show=False,
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min', 'china': 'https://echarts-maps.github.io/echarts-countries-js/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="c5f41a6fc28f45528defb1d8a8b83733" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_c5f41a6fc28f45528defb1d8a8b83733 = echarts.init(document.getElementById('c5f41a6fc28f45528defb1d8a8b83733'), 'light', {renderer: 'canvas'});
#
# var option_c5f41a6fc28f45528defb1d8a8b83733 = {
#     "title": [
#         {
#             "text": "\u65b0\u51a0\u75ab\u60c5\u6570\u636e",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1989960,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5404\u7701\u7d2f\u79ef\u786e\u8bca\u4eba\u6570",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": "189"
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": "147"
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": "3686338"
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": "337306"
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": "185"
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": "40295"
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": "1008"
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": "122"
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": "2097"
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": "682"
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": "2008"
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": "423"
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": "1718"
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": "2988"
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": "288"
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": "2007"
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": "3329"
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": "2174"
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": "1649"
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": "3422"
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": "63240"
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": "3680"
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": "2247"
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": "2374"
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": "2751"
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": "1389"
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": "732"
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": "1065"
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": "1401"
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": "3183"
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": "7443"
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": "3155"
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": "68402"
#                 },
#                 {
#                     "name": "\u7701\u4efd",
#                     "value": "\u7d2f\u79ef\u786e\u8bca"
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": "189"
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": "147"
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": "3686338"
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": "337306"
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": "185"
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": "40295"
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": "1008"
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": "122"
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": "2097"
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": "682"
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": "2008"
#                 },
#                 {
#                     "name": "\u5c71\u897f",

# %%
from ipywidgets import Tab
from pyecharts import Map
import pandas as pd
from pyecharts import online
online()
data = pd.read_csv('新冠疫情各省数据.csv')
atr = []
for i in data['省份']:
    atr.append(i)


valuezy = data['累积治愈']
map = Map("新冠疫情数据", width=800, height=600)
map.add(
    "各省累积治愈人数",
    atr,
    valuezy,
    maptype="china",
    is_label_show=True,
    is_visualmap=True,
    visual_range = [1,20000],
    visual_text_color='green',
    visual_range_color=['white','Light green','green'],
    is_map_symbol_show=False,
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min', 'china': 'https://echarts-maps.github.io/echarts-countries-js/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="7bca7e69efcd4c3b992869de6f395a83" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_7bca7e69efcd4c3b992869de6f395a83 = echarts.init(document.getElementById('7bca7e69efcd4c3b992869de6f395a83'), 'light', {renderer: 'canvas'});
#
# var option_7bca7e69efcd4c3b992869de6f395a83 = {
#     "title": [
#         {
#             "text": "\u65b0\u51a0\u75ab\u60c5\u6570\u636e",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4391270,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5404\u7701\u7d2f\u79ef\u6cbb\u6108\u4eba\u6570",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": "83"
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": "147"
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": "13742"
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": "63798"
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": "183"
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": "40290"
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": "1005"
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": "122"
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": "2038"
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": "679"
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": "1985"
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": "422"
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": "1714"
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": "2974"
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": "282"
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": "1999"
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": "3312"
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": "2156"
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": "1647"
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": "3374"
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": "62560"
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": "3625"
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": "2238"
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": "2355"
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": "2730"
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": "1382"
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": "715"
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": "1059"
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": "1395"
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": "3161"
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": "7343"
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": "3143"
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": "63887"
#                 },
#                 {
#                     "name": "\u7701\u4efd",
#                     "value": "\u7d2f\u79ef\u6cbb\u6108"
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": "83"
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": "147"
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": "13742"
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": "63798"
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": "183"
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": "40290"
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": "1005"
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": "122"
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": "2038"
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": "679"
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": "1985"
#                 },
#                 {
#                     "name": "\u5c71\u897f",

# %%
from ipywidgets import Tab
from pyecharts import Map
import pandas as pd
from pyecharts import online
online()
data = pd.read_csv('新冠疫情各省数据.csv')
atr = []
for i in data['省份']:
    atr.append(i)


valuexy = data['现有确诊']
map = Map("新冠疫情数据", width=800, height=600)
map.add(
    "各省现有确诊人数",
    atr,
    valuexy,
    maptype="china",
    is_label_show=True,
    is_visualmap=True,
    visual_range = [1,200],
    visual_text_color='green',
    visual_range_color=['white','orange','red'],
    is_map_symbol_show=False,
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min', 'china': 'https://echarts-maps.github.io/echarts-countries-js/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="34614d2093194922acf51ec273da2d7d" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_34614d2093194922acf51ec273da2d7d = echarts.init(document.getElementById('34614d2093194922acf51ec273da2d7d'), 'light', {renderer: 'canvas'});
#
# var option_34614d2093194922acf51ec273da2d7d = {
#     "title": [
#         {
#             "text": "\u65b0\u51a0\u75ab\u60c5\u6570\u636e",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4713441,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5404\u7701\u73b0\u6709\u786e\u8bca\u4eba\u6570",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": "106"
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": "3666148"
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": "264109"
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": "58"
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": "20"
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": "2"
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": "14"
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": "16"
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": "47"
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": "85"
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": "46"
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": "9"
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": "16"
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": "14"
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": "6"
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": "11"
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": "2"
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": "92"
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": "11"
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": "3"
#                 },
#                 {
#                     "name": "\u7701\u4efd",
#                     "value": "\u73b0\u6709\u786e\u8bca"
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": "106"
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": "3666148"
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": "264109"
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": "0"
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": "58"
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": "20"
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": "1"
#                 },
#                 {
#                     "name": "\u8fb

# %%
#新增确诊病例排序
top=data.sort_values('新增确诊',ascending=False).head(5)
top
# Out:
#     省份     累积确诊   累积治愈     现有确诊   新增确诊  累积死亡
# 34  省份     累积确诊   累积治愈     现有确诊   新增确诊  累积死亡
# 31  广东     7443   7343       92      7     8
# 66  广东     7443   7343       92      7     8
# 38  台湾  3686338  13742  3666148  44417  6448
# 3   台湾  3686338  13742  3666148  44417  6448
